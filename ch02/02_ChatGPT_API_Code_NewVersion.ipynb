# %% [markdown]
# # 패키지 불러오기

# %%
import openai

# %% [markdown]
# # 기본 질문하기

# %%
client = openai.OpenAI(api_key = "api key 입력")

response = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[{"role": "user", "content": "Tell me how to make a pizza"}])

# %%
print(response)
# Out:
# ChatCompletion(id='chatcmpl-8L07P3XCYU2YX6v5Qq8DhULu6lmrV', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='Making a pizza involves several steps, including preparing the dough, adding toppings, and baking it. Here is a basic recipe to make your own pizza at home:\n\nIngredients:\n- 2 ¼ cups all-purpose flour\n- 1 teaspoon instant yeast\n- 1 teaspoon sugar\n- 1 teaspoon salt\n- ¾ cup warm water\n- 2 tablespoons olive oil\n- Tomato sauce\n- Cheese (mozzarella or a blend of your choice)\n- Desired toppings (e.g., pepperoni, vegetables, etc.)\n\nInstructions:\n\n1. Prepare the dough: In a large bowl, combine flour, yeast, sugar, and salt. Mix well. Make a well in the center and add warm water and olive oil. Stir until a soft dough forms.\n2. Knead the dough: Transfer the dough to a floured surface and knead for about 5-7 minutes until smooth and elastic. Add more flour if the dough becomes too sticky.\n3. Let the dough rise: Shape the dough into a ball and place it in a greased bowl. Cover the bowl with a clean cloth or plastic wrap and let the dough rise in a warm place for about 1-2 hours or until it doubles in size.\n4. Preheat the oven: Preheat your oven to 475°F (245°C) or the highest temperature your oven can reach. Place an empty baking sheet or pizza stone in the oven while preheating.\n5. Roll out the dough: Once the dough has risen, remove it from the bowl and place it on a floured surface. Roll it into a round or rectangular shape, depending on your preference, to about ¼-inch thickness. Prick the dough gently with a fork to avoid bubbling.\n6. Add sauce and toppings: Spread tomato sauce evenly on the dough, leaving a small border around the edges for the crust. Sprinkle your desired amount of cheese evenly over the sauce. Add your chosen toppings.\n7. Bake the pizza: Carefully transfer the pizza onto the preheated baking sheet or pizza stone in the oven. Bake for about 12-15 minutes or until the cheese is melted and bubbly while the crust turns golden brown.\n8. Allow to cool and serve: Once the pizza is baked to your liking, remove it from the oven and let it cool for a few minutes. Slice it into pieces and serve while still warm.\n\nRemember, this is a basic pizza recipe, and you can customize it by adding your favorite toppings or experimenting with different sauces and cheeses. Enjoy making and savoring your homemade pizza!', role='assistant', function_call=None, tool_calls=None))], created=1700016035, model='gpt-3.5-turbo-0613', object='chat.completion', system_fingerprint=None, usage=CompletionUsage(completion_tokens=525, prompt_tokens=14, total_tokens=539))

# %% [markdown]
# # 응답에서 답변만 추출하기

# %%
print(response.choices[0].message.content)
# Out:
# 2020년 월드시리즈에서는 로스앤젤레스 다저스가 우승했어요.

# %% [markdown]
# # 소모 토큰, 비용 확인하기

# %%
print(response.usage)
# Out:
# CompletionUsage(completion_tokens=525, prompt_tokens=14, total_tokens=539)

# %%
total_bill = response.usage.prompt_tokens * 0.0015/1000 + response.usage.completion_tokens * 0.002/1000
total_bill
# Out:
# 0.0010710000000000001

# %%
print("총 발생 비용 {} 원".format(total_bill*1323.43))
# Out:
# 총 발생 비용 1.48356503 원

# %% [markdown]
# # 역할 부여하기

# %%
response = client.chat.completions.create(
 model="gpt-3.5-turbo",
 messages=[
         {"role": "system", "content": "너는 친절하게 답변해주는 비서야"},
        {"role": "user", "content": "2020년 월드시리즈에서는 누가 우승했어?"}
 ]
)
print(response.choices[0].message.content)
# Out:
# 2020년 월드시리즈에서는 로스앤젤레스 다저스가 우승했어요!

# %%
response = client.chat.completions.create(
 model="gpt-3.5-turbo",
 messages=[
 {"role": "system", "content": "You're a chatbot that refuses to answer and says sorry when users ask questions."},
 {"role": "user", "content": "2020년 월드시리즈에서는 누가 우승했어?"}
 ]
)
print(response.choices[0].message.content)
# Out:
# Sorry, I can't answer that question.

# %%
response = client.chat.completions.create(
 model="gpt-3.5-turbo",
 messages=[
  {"role": "system", "content": "You are a translator who translates user input."},
  {"role": "user", "content": "2020년 월드시리즈에서는 누가 우승했어?"}
  ]
 )
print(response.choices[0].message.content)
# Out:
# Who won the World Series in 2020?

# %%
response = client.chat.completions.create(
 model="gpt-3.5-turbo",
 messages=[
 {"role": "system", "content": "You are a chatbot that answers questions in English even in Korean."},
 {"role": "user", "content": "2020년 월드시리즈에서는 누가 우승했어?"}
 ]
)
print(response.choices[0].message.content)
# Out:
# 2020년 월드시리즈에서는 로스앤젤레스 다저스가 우승했습니다.

# %% [markdown]
# # 이전 대화를 포함하여 답변하기

# %%
response = client.chat.completions.create(
 model="gpt-3.5-turbo",
 messages=[
 {"role": "user", "content": "2002년 월드컵에서 가장 화제가 되었던 나라는 어디야?"}, # 이전 질문
 {"role": "assistant", "content": "바로 예상을 뚫고 4강 진출 신화를 일으킨 한국입니다."}, # 이전 답변
 {"role": "user", "content": "그 나라가 화제가 되었던 이유를 자세하게 설명해줘"} # 마지막 질문
 ]
)
print(response.choices[0].message.content)
# Out:
# 2002년 월드컵에서 한국은 기존의 예상을 깨고 많은 사람들을 놀라게 했습니다. 그래서 화제가 되었던 이유는 여러 가지가 있습니다.
#
# 1. 역대 최고 실적: 한국은 이전 월드컵에서 좋은 성적을 거두지 못했기 때문에 기대가 크지 않았습니다. 하지만 한국은 올해 월드컵에서 역대 최고 실적인 4강에 진출하여 많은 사람들을 놀라게 했습니다.
#
# 2. 호주와의 조직적인 승리: 첫 경기에서 호주와 맞붙었을 때, 한국은 조직적이고 전략적인 플레이를 통해 2-1로 승리하였습니다. 이로써 멕시코와의 경기에서 승점이 크게 중요해지고, 한국은 놀라운 경기력을 보여주며 1-0으로 승리하였습니다.
#
# 3. 이태리와의 경기: 16강에서 한국은 강력한 이태리와 맞대결을 하였습니다. 이태리는 강팀으로 알려져 있었고, 한국은 상대적으로 어려운 상황이었습니다. 하지만 90분동안 스코어를 지키며 무승부로 맞섰고, 연장전에서 한국은 이태리에게 패널티킥으로 2골을 넣어 승리하였습니다.
#
# 4. 세계 각국에서의 지지와 관심: 한국의 놀라운 실적으로 인해 세계 각국에서 많은 사람들이 한국을 응원하고 지지하는 움직임이 생겼습니다. 많은 관객들이 한국을 응원하기 위해 한국 뿐만 아니라 독일, 일본 등 다른 지역으로 여행을 와 응원하는 모습이 보였습니다.
#
# 이처럼 한국이 2002년 월드컵에서 화제가 되었던 이유는 예상하던 것과 다른 경기력과 실적을 보여주었기 때문입니다. 이로 인해 한국은 월드컵 역사에 긍정적인 기록을 남기며 많은 사람들의 기억에 남게 되었습니다.

# %%
response = client.chat.completions.create(
 model="gpt-3.5-turbo",
 messages=[
 {"role": "user", "content": "2002년 월드컵에서 가장 화제가 되었던 나라가 어디야?"} # 마지막 질문
 ]
)
print(response.choices[0].message.content)
# Out:
# 2002년 월드컵에서 가장 화제가 되었던 나라는 한국이었습니다. 한국은 2002년 월드컵에서 세계 각국의 강호들을 상대로 높은 실력을 보여주며 기록을 썼고, 올해의 주최국과 함께 일본과 공동 개최국으로서 세계적인 주목을 받았습니다. 한국은 캄보디아, 폴란드, 미국 등을 상대로 그룹 스테이지를 통과하고, 이탈리아, 스페인, 포르투갈 등 세계 강호들을 이긴 끝에 무려 4강에 진출하는 기적을 이루었습니다. 이러한 결과로 인해 한국은 전 세계의 축구 팬들의 관심을 받았고, 월드컵 역사상 가장 화제가 된 나라 중 하나로 손꼽히게 되었습니다.
